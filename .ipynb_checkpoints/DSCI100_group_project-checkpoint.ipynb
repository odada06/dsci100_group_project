# %% [markdown]
# **DSCI 100 PLAICraft Group Project**

# %%
library(tidyverse)
library(repr)
library(tidymodels)
library(lubridate)
library(dplyr)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# ── Attaching packages ────────────────────────────────────── tidymodels 1.1.1 ──
#
# ✔ broom        1.0.6     ✔ rsample      1.2.1
# ✔ dials        1.3.0     ✔ tune         1.1.2
# ✔ infer        1.0.7     ✔ workflows    1.1.4
# ✔ modeldata    1.4.0     ✔ workflowsets 1.0.1
# ✔ parsnip      1.2.1     ✔ yardstick    1.3.1
# ✔ recipes      1.1.0
#
# ── Conflicts ───────────────────────────────────────── tidymodels_conflicts() ──
# ...

# %%
set.seed(1)

# %%
players_data <- read_csv("data/players.csv")
players_data
# Out:
# Rows: 196 Columns: 9
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (4): experience, hashedEmail, name, gender
# dbl (2): played_hours, age
# lgl (3): subscribe, individualId, organizationName
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#     experience subscribe
# 1   Pro         TRUE
# 2   Veteran     TRUE
# 3   Veteran    FALSE
# 4   Amateur     TRUE
# 5   Regular     TRUE
# 6   Amateur     TRUE
# 7   Regular     TRUE
# 8   Amateur    FALSE
# 9   Amateur     TRUE
# 10  Veteran     TRUE
# 11  Veteran     TRUE
# 12  Pro         TRUE
# 13  Beginner    TRUE
# 14  Amateur     TRUE
# 15  Veteran     TRUE
# 16  Amateur    FALSE
# 17  Beginner    TRUE
# 18  Amateur     TRUE
# 19  Amateur     TRUE
# 20  Regular     TRUE
# 21  Regular     TRUE
# 22  Amateur    FALSE
# 23  Beginner    TRUE
# 24  Beginner    TRUE
# ...

# %%
players <- players_data |>
        select(experience, played_hours, gender, age, hashedEmail) |>
        mutate(experience = as_factor(experience), gender = as_factor(gender)) |>
        mutate(much_time = played_hours > 3) |>
        filter(played_hours > 0)
players
# Out:
#     experience played_hours gender            age
# 1   Pro        30.3         Male               9
# 2   Veteran     3.8         Male              17
# 3   Amateur     0.7         Female            21
# 4   Regular     0.1         Male              21
# 5   Amateur     0.1         Male              17
# 6   Veteran     1.6         Female            23
# 7   Beginner    1.5         Female            25
# 8   Amateur     0.2         Male              22
# 9   Amateur    48.4         Female            17
# 10  Amateur     0.5         Male              17
# 11  Regular     0.6         Male              19
# 12  Regular     0.3         Male               8
# 13  Amateur     0.1         Female            17
# 14  Beginner    1.0         Male              17
# 15  Amateur     0.7         Female            21
# 16  Regular     0.6         Female            28
# 17  Amateur     1.8         Male              23
# 18  Veteran     0.1         Male              18
# ...

# %%
sessions_data <- read_csv("data/sessions.csv")
sessions_data
# Out:
# Rows: 1535 Columns: 5
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (3): hashedEmail, start_time, end_time
# dbl (2): original_start_time, original_end_time
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#      hashedEmail
# 1    bfce39c89d6549f2bb94d8064d3ce69dc3d7e72b38f431d8aa0c4bf95ccee6bf
# 2    36d9cbb4c6bc0c1a6911436d2da0d09ec625e43e6552f575d4acc9cf487c4686
# 3    f8f5477f5a2e53616ae37421b1c660b971192bd8ff77e3398304c7ae42581fdc
# 4    bfce39c89d6549f2bb94d8064d3ce69dc3d7e72b38f431d8aa0c4bf95ccee6bf
# 5    36d9cbb4c6bc0c1a6911436d2da0d09ec625e43e6552f575d4acc9cf487c4686
# 6    bfce39c89d6549f2bb94d8064d3ce69dc3d7e72b38f431d8aa0c4bf95ccee6bf
# 7    fd6563a4e0f6f4273580e5fedbd8dda64990447aea5a33cbb5e894a3867ca44d
# 8    ad6390295640af1ed0e45ffc58a53b2d9074b0eea694b16210addd44d7c81f83
# ...

# %%
sessions_tidy <- sessions_data |>
        mutate(start_date = dmy_hm(start_time), end_date = dmy_hm(end_time)) |>
        mutate(session_length = end_date - start_date) |>
        select(-start_time, -end_time) |>
        separate(start_date, into = c("start_date", "start_time"), sep = " ") |>
        separate(end_date, into = c("end_date", "end_time"), sep = " ") |>
        rename(unix_start_time = original_start_time, unix_end_time = original_end_time)
sessions_tidy
# Out:
# Warning message:
# “Expected 2 pieces. Missing pieces filled with `NA` in 3 rows [106, 1221, 1222].”
# Warning message:
# “Expected 2 pieces. Missing pieces filled with `NA` in 4 rows [52, 1063, 1066,
# 1238].”
#      hashedEmail
# 1    bfce39c89d6549f2bb94d8064d3ce69dc3d7e72b38f431d8aa0c4bf95ccee6bf
# 2    36d9cbb4c6bc0c1a6911436d2da0d09ec625e43e6552f575d4acc9cf487c4686
# 3    f8f5477f5a2e53616ae37421b1c660b971192bd8ff77e3398304c7ae42581fdc
# 4    bfce39c89d6549f2bb94d8064d3ce69dc3d7e72b38f431d8aa0c4bf95ccee6bf
# 5    36d9cbb4c6bc0c1a6911436d2da0d09ec625e43e6552f575d4acc9cf487c4686
# 6    bfce39c89d6549f2bb94d8064d3ce69dc3d7e72b38f431d8aa0c4bf95ccee6bf
# 7    fd6563a4e0f6f4273580e5fedbd8dda64990447aea5a33cbb5e894a3867ca44d
# 8    ad6390295640af1ed0e45ffc58a53b2d9074b0eea694b16210addd44d7c81f83
# 9    96e190b0bf3923cd8d349eee467c09d1130af143335779251492eb4c2c058a5f
# 10   36d9cbb4c6bc0c1a6911436d2da0d09ec625e43e6552f575d4acc9cf487c4686
# ...

# %%
sessions <- sessions_tidy |>
        group_by(hashedEmail) |>
        summarize(session_amount = n())
sessions
# Out:
#     hashedEmail
# 1   0088b5e134c3f0498a18c7ea6b8d77b4b0ff1636fc93355ccc95b45423367832
# 2   060aca80f8cfbf1c91553a72f4d5ec8034764b05ab59fe8e1cf0eee9a7b67967
# 3   0ce7bfa910d47fc91f21a7b3acd8f33bde6db57912ce0290fa0437ce0b97f387
# 4   0d4d71be33e2bc7266ee4983002bd930f69d304288a8663529c875f40f1750f3
# 5   0d70dd9cac34d646c810b1846fe6a85b9e288a76f5dcab9c1ff1a0e7ca200b3a
# 6   11006065e9412650e99eea4a4aaaf0399bc338006f85e80cc82d18b49f0e2aa4
# 7   119f01b9877fc5ea0073d05602a353b91c4b48e4cf02f42bb8d661b46a34b760
# 8   18936844e06b6c7871dce06384e2d142dd86756941641ef39cf40a9967ea14e3
# 9   1a2b92f18f36b0b59b41d648d10a9b8b20a2adff550ddbcb8cec2f47d4d881d0
# 10  1d2371d8a35c8831034b25bda8764539ab7db0f63938696917c447128a2540dd
# 11  200db0417ee70863c7e2a0f214c737476fb86de5869d0b907a077d726357e687
# 12  20ae3f8b5323674fe6e537bc91928841cfc2a00c1b36522fd25370bb6fa89d36
# 13  22a78bfd44e46931261d06864b92cf9a8fd77fb02bec66cb71646dd9da222a0d
# ...

# %%
plaicraft <- left_join(sessions, players, by = "hashedEmail") |>
        filter(experience != "NA") |>
        mutate(much_time_1 = as_factor(much_time)) |>
        mutate(much_time_2 = fct_recode(much_time_1, "1" = "TRUE", "2" = "FALSE")) |>
        mutate(much_time_3 = as.numeric(much_time_2)) |>
        select(-much_time_1, -much_time_2)
plaicraft
# Out:
#     hashedEmail
# 1   0088b5e134c3f0498a18c7ea6b8d77b4b0ff1636fc93355ccc95b45423367832
# 2   060aca80f8cfbf1c91553a72f4d5ec8034764b05ab59fe8e1cf0eee9a7b67967
# 3   0ce7bfa910d47fc91f21a7b3acd8f33bde6db57912ce0290fa0437ce0b97f387
# 4   0d4d71be33e2bc7266ee4983002bd930f69d304288a8663529c875f40f1750f3
# 5   0d70dd9cac34d646c810b1846fe6a85b9e288a76f5dcab9c1ff1a0e7ca200b3a
# 6   11006065e9412650e99eea4a4aaaf0399bc338006f85e80cc82d18b49f0e2aa4
# 7   119f01b9877fc5ea0073d05602a353b91c4b48e4cf02f42bb8d661b46a34b760
# 8   18936844e06b6c7871dce06384e2d142dd86756941641ef39cf40a9967ea14e3
# 9   1a2b92f18f36b0b59b41d648d10a9b8b20a2adff550ddbcb8cec2f47d4d881d0
# 10  200db0417ee70863c7e2a0f214c737476fb86de5869d0b907a077d726357e687
# 11  20ae3f8b5323674fe6e537bc91928841cfc2a00c1b36522fd25370bb6fa89d36
# 12  22a78bfd44e46931261d06864b92cf9a8fd77fb02bec66cb71646dd9da222a0d
# 13  23fe711e0e3b77f1da7aa221ab1192afe21648d47d2b4fa7a5a659ff443a0eb5
# ...

# %%
options(repr.plot.with = 10, repr.plot.height = 8)
players_age_plot <- plaicraft |>
        ggplot(aes(x = age, y = played_hours, colour = experience)) +
        geom_point(alpha = 0.5) +
        labs(x = "Age", y = "Number of Hours Played", title = "Time Spent Playing PLAIcraft \n Based on Age and Experience", 
             colour = "Level of Experience") +
        theme(text = element_text(size = 16))
players_age_plot
# Out:
# plot without title

# %%
options(repr.plot.with = 10, repr.plot.height = 8)
players_age_plot <- plaicraft |>
        ggplot(aes(x = session_amount, y = played_hours, colour = experience)) +
        geom_point(alpha = 0.5) +
        labs(x = "Number of PLAIcraft Sessions", y = "Number of Hours Played", colour = "Level of Experience",
             title = "Time Spent Playing PLAIcraft \n Based on Number of Sessions and Experience") +
        theme(text = element_text(size = 16))
players_age_plot
# Out:
# plot without title

# %%
count <- plaicraft |>
    group_by(experience) |>
    summarize(count = n()) |>
    arrange(count)
count

counts <- players_data |>
    group_by(experience) |>
    summarize(count = n()) |>
    arrange(count)
counts
# Out:
#   experience count
# 1 Pro        11
# 2 Beginner   19
# 3 Regular    20
# 4 Veteran    26
# 5 Amateur    35
#   experience count
# 1 Pro        14
# 2 Beginner   35
# 3 Regular    36
# 4 Veteran    48
# 5 Amateur    63

# %%
plaicraft_split <- initial_split(plaicraft, prop = 0.7, strata = experience)

plaicraft_train <- training(plaicraft_split)

plaicraft_test <- testing(plaicraft_split)

recipe <- recipe(experience ~ played_hours + session_amount, data = plaicraft_train) |>
         step_scale(played_hours, session_amount) |>
         step_center(played_hours, session_amount)

test_ks <- tibble(neighbors = seq(from = 1, to = 15, by = 1))

vfold <- vfold_cv(plaicraft_train, v = 10, strata = experience)

spec_1 <- nearest_neighbor(weight_func = "rectangular", neighbors = tune()) |>
        set_engine("kknn") |>
        set_mode("classification")

workflow_1 <- workflow() |>
        add_recipe(recipe) |>
        add_model(spec_1) |>
        tune_grid(resamples = vfold, grid = test_ks) |>
        collect_metrics() |>
        filter(.metric == "accuracy")

options(repr.plot.width = 8, repr.plot.height = 8)
k_plot <- ggplot(workflow_1, aes(x = neighbors, y = mean)) +
        geom_point() +
        geom_line() +
        labs(x = "Number of Neighbours", y = "Average Accuracy", title = "Comparing the Accuracy of Various K Values") +
        theme(text = element_text(size = 14))
k_plot
# Out:
# → A | warning: ✖ No observations were detected in `truth` for level: Pro.
#                ℹ Computation will proceed by ignoring those levels.
#
# There were issues with some computations   A: x1
#
# There were issues with some computations   A: x3
#
# There were issues with some computations   A: x5
#
# → B | warning: ✖ No observations were detected in `truth` for level: Beginner.
#                ℹ Computation will proceed by ignoring those levels.
#
# There were issues with some computations   A: x5
# → C | warning: ✖ No observations were detected in `truth` for level: Regular.
#                ℹ Computation will proceed by ignoring those levels.
#
# There were issues with some computations   A: x5
# There were issues with some computations   A: x5   B: x1   C: x1
#
# There were issues with some computations   A: x5   B: x2   C: x1
# plot without title

# %%
workflow_1
# Out:
#    neighbors .metric  .estimator mean      n  std_err    .config
# 1   1        accuracy multiclass 0.2312302 10 0.04507288 Preprocessor1_Model01
# 2   2        accuracy multiclass 0.2201190 10 0.04362241 Preprocessor1_Model02
# 3   3        accuracy multiclass 0.2201190 10 0.04362241 Preprocessor1_Model03
# 4   4        accuracy multiclass 0.2321825 10 0.04079424 Preprocessor1_Model04
# 5   5        accuracy multiclass 0.2113492 10 0.04744974 Preprocessor1_Model05
# 6   6        accuracy multiclass 0.2353571 10 0.05994380 Preprocessor1_Model06
# 7   7        accuracy multiclass 0.2278571 10 0.05627407 Preprocessor1_Model07
# 8   8        accuracy multiclass 0.2611905 10 0.04812175 Preprocessor1_Model08
# 9   9        accuracy multiclass 0.2723016 10 0.04548179 Preprocessor1_Model09
# 10 10        accuracy multiclass 0.2723016 10 0.04548179 Preprocessor1_Model10
# 11 11        accuracy multiclass 0.2611905 10 0.04812175 Preprocessor1_Model11
# ...

# %%
recipe_age <- recipe(experience ~ played_hours + session_amount + age, data = plaicraft_train) |>
         step_scale(played_hours, session_amount, age) |>
         step_center(played_hours, session_amount, age)

workflow_2 <- workflow() |>
        add_recipe(recipe_age) |>
        add_model(spec_1) |>
        tune_grid(resamples = vfold, grid = test_ks) |>
        collect_metrics() |>
        filter(.metric == "accuracy")

options(repr.plot.width = 8, repr.plot.height = 8)
k_plot <- ggplot(workflow_2, aes(x = neighbors, y = mean)) +
        geom_point() +
        geom_line() +
        labs(x = "Number of Neighbours", y = "Average Accuracy", title = "Comparing the Accuracy of Various K Values") +
        theme(text = element_text(size = 14))
k_plot
# Out:
# → A | warning: ✖ No observations were detected in `truth` for level: Pro.
#                ℹ Computation will proceed by ignoring those levels.
#
# There were issues with some computations   A: x1
#
# There were issues with some computations   A: x2
# plot without title

# %%
workflow_2
# Out:
#    neighbors .metric  .estimator mean      n  std_err    .config
# 1   1        accuracy multiclass 0.2102381 10 0.03976151 Preprocessor1_Model01
# 2   2        accuracy multiclass 0.2100794 10 0.03671817 Preprocessor1_Model02
# 3   3        accuracy multiclass 0.1682937 10 0.05010132 Preprocessor1_Model03
# 4   4        accuracy multiclass 0.1334524 10 0.04218478 Preprocessor1_Model04
# 5   5        accuracy multiclass 0.1669048 10 0.05119195 Preprocessor1_Model05
# 6   6        accuracy multiclass 0.1353571 10 0.05103923 Preprocessor1_Model06
# 7   7        accuracy multiclass 0.1204762 10 0.04462576 Preprocessor1_Model07
# 8   8        accuracy multiclass 0.1586905 10 0.04557658 Preprocessor1_Model08
# 9   9        accuracy multiclass 0.1905159 10 0.04496111 Preprocessor1_Model09
# 10 10        accuracy multiclass 0.1948016 10 0.04171944 Preprocessor1_Model10
# 11 11        accuracy multiclass 0.1545238 10 0.03704989 Preprocessor1_Model11
# ...

# %%
recipe_time <- recipe(experience ~ played_hours + session_amount + much_time_3, data = plaicraft_train) |>
         step_scale(played_hours, session_amount, much_time_3) |>
         step_center(played_hours, session_amount, much_time_3)

workflow_3 <- workflow() |>
        add_recipe(recipe_time) |>
        add_model(spec_1) |>
        tune_grid(resamples = vfold, grid = test_ks) |>
        collect_metrics() |>
        filter(.metric == "accuracy")

options(repr.plot.width = 8, repr.plot.height = 8)
k_plot <- ggplot(workflow_3, aes(x = neighbors, y = mean)) +
        geom_point() +
        geom_line() +
        labs(x = "Number of Neighbours", y = "Average Accuracy", title = "Comparing the Accuracy of Various K Values") +
        theme(text = element_text(size = 14))
k_plot
# Out:
# → A | warning: ✖ No observations were detected in `truth` for level: Pro.
#                ℹ Computation will proceed by ignoring those levels.
#
# There were issues with some computations   A: x1
#
# There were issues with some computations   A: x2
#
# There were issues with some computations   A: x4
#
# → B | warning: ✖ No observations were detected in `truth` for level: Beginner.
#                ℹ Computation will proceed by ignoring those levels.
#
# There were issues with some computations   A: x4
# → C | warning: ✖ No observations were detected in `truth` for level: Regular.
#                ℹ Computation will proceed by ignoring those levels.
#
# There were issues with some computations   A: x4
# There were issues with some computations   A: x5   B: x1   C: x1
#
# There were issues with some computations   A: x5   B: x2   C: x1
# plot without title

# %%
workflow_3
# Out:
#    neighbors .metric  .estimator mean      n  std_err    .config
# 1   1        accuracy multiclass 0.2312302 10 0.04507288 Preprocessor1_Model01
# 2   2        accuracy multiclass 0.2201190 10 0.04362241 Preprocessor1_Model02
# 3   3        accuracy multiclass 0.2201190 10 0.04362241 Preprocessor1_Model03
# 4   4        accuracy multiclass 0.2178968 10 0.04121055 Preprocessor1_Model04
# 5   5        accuracy multiclass 0.1970635 10 0.04711135 Preprocessor1_Model05
# 6   6        accuracy multiclass 0.2210714 10 0.05133483 Preprocessor1_Model06
# 7   7        accuracy multiclass 0.2246825 10 0.04826784 Preprocessor1_Model07
# 8   8        accuracy multiclass 0.2580159 10 0.04214950 Preprocessor1_Model08
# 9   9        accuracy multiclass 0.2691270 10 0.03920854 Preprocessor1_Model09
# 10 10        accuracy multiclass 0.2580159 10 0.04214950 Preprocessor1_Model10
# 11 11        accuracy multiclass 0.2469048 10 0.04459166 Preprocessor1_Model11
# ...
