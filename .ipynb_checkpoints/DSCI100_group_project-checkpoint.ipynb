# %% [markdown]
# # DSCI 100 PLAICraft Group Project
#
# Authors: Deborah Dada, Luke Huang, Fiona Ma, Michael Toy

# %% [markdown]
# ## **Introduction**
#
# PLAICraft is a project run on the popular sandbox adventure game Minecraft, released in 2009. With Minecraft’s immense popularity, with more than 170 million active players per month (Kumar, 2021), players contribute many hours to their online worlds. Thus using Minecraft as a medium, the PLAI research group has set up an online server to collect more than ten thousand hours of data from online participants and their behaviour in-game. This data will create and train human-like AI within the gaming industry. However, the resources to host the server for players are limited and the PLAI research group would like a few questions answered to better optimize their project. The question we tried to answer was what types of players are likely to contribute a large amount of data?
#
# For our question, we worked under the assumption that the hours played were equivalent to the data collected. Furthermore, the dataset that we used to answer our question was split among “players.csv” and “sessions.csv” files which included player information, played time, and logged session. Specifically, the “players.csv” file held the player's personal information (name, age, gender, and experience), their total played hours, hashed email, and whether they subscribed to the email. The “sessions.csv” file included each unique session a player logged on to the server with each observation including the player’s hashed email and their start and end times.

# %% [markdown]
# ## **Methods & Results**
#
# We first load in the libraries which will be used throughout this project, set seed, and also read in the datasets through URL so it is replicable.

# %%
library(tidyverse)
library(repr)
library(tidymodels)
library(lubridate)
library(dplyr)
library(themis)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# ── Attaching packages ────────────────────────────────────── tidymodels 1.1.1 ──
#
# ✔ broom        1.0.6     ✔ rsample      1.2.1
# ✔ dials        1.3.0     ✔ tune         1.1.2
# ✔ infer        1.0.7     ✔ workflows    1.1.4
# ✔ modeldata    1.4.0     ✔ workflowsets 1.0.1
# ✔ parsnip      1.2.1     ✔ yardstick    1.3.1
# ✔ recipes      1.1.0
#
# ── Conflicts ───────────────────────────────────────── tidymodels_conflicts() ──
# ...

# %%
set.seed(1)

# %%
url_players <- "https://drive.google.com/uc?export=download&id=1Mw9vW0hjTJwRWx0bDXiSpYsO3gKogaPz"
url_sessions <- "https://drive.google.com/uc?export=download&id=14O91N5OlVkvdGxXNJUj5jIsV5RexhzbB"

# %%
players_data <- read_csv(url_players)
head(players_data)
# Out:
# Rows: 196 Columns: 9
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (4): experience, hashedEmail, name, gender
# dbl (2): played_hours, age
# lgl (3): subscribe, individualId, organizationName
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   experience subscribe
# 1 Pro         TRUE
# 2 Veteran     TRUE
# 3 Veteran    FALSE
# 4 Amateur     TRUE
# 5 Regular     TRUE
# 6 Amateur     TRUE
#   hashedEmail                                                      played_hours
# 1 f6daba428a5e19a3d47574858c13550499be23603422e6a0ee9728f8b53e192d 30.3
# 2 f3c813577c458ba0dfef80996f8f32c93b6e8af1fa939732842f2312358a88e9  3.8
# 3 b674dd7ee0d24096d1c019615ce4d12b20fcbff12d79d3c5a9d2118eb7ccbb28  0.0
# 4 23fe711e0e3b77f1da7aa221ab1192afe21648d47d2b4fa7a5a659ff443a0eb5  0.7
# ...

# %%
players <- players_data |>
        select(experience, played_hours, gender, age, hashedEmail) |>
        mutate(experience = as_factor(experience), gender = as_factor(gender)) |>
        mutate(much_time = played_hours >= 3)
head(players)
# Out:
#   experience played_hours gender age
# 1 Pro        30.3         Male    9
# 2 Veteran     3.8         Male   17
# 3 Veteran     0.0         Male   17
# 4 Amateur     0.7         Female 21
# 5 Regular     0.1         Male   21
# 6 Amateur     0.0         Female 17
#   hashedEmail                                                      much_time
# 1 f6daba428a5e19a3d47574858c13550499be23603422e6a0ee9728f8b53e192d  TRUE
# 2 f3c813577c458ba0dfef80996f8f32c93b6e8af1fa939732842f2312358a88e9  TRUE
# 3 b674dd7ee0d24096d1c019615ce4d12b20fcbff12d79d3c5a9d2118eb7ccbb28 FALSE
# 4 23fe711e0e3b77f1da7aa221ab1192afe21648d47d2b4fa7a5a659ff443a0eb5 FALSE
# 5 7dc01f10bf20671ecfccdac23812b1b415acd42c2147cb0af4d48fcce2420f3e FALSE
# 6 f58aad5996a435f16b0284a3b267f973f9af99e7a89bee0430055a44fa92f977 FALSE

# %%
sessions_data <- read_csv(url_sessions)
head(sessions_data)
# Out:
# Rows: 1535 Columns: 5
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (3): hashedEmail, start_time, end_time
# dbl (2): original_start_time, original_end_time
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   hashedEmail
# 1 bfce39c89d6549f2bb94d8064d3ce69dc3d7e72b38f431d8aa0c4bf95ccee6bf
# 2 36d9cbb4c6bc0c1a6911436d2da0d09ec625e43e6552f575d4acc9cf487c4686
# 3 f8f5477f5a2e53616ae37421b1c660b971192bd8ff77e3398304c7ae42581fdc
# 4 bfce39c89d6549f2bb94d8064d3ce69dc3d7e72b38f431d8aa0c4bf95ccee6bf
# 5 36d9cbb4c6bc0c1a6911436d2da0d09ec625e43e6552f575d4acc9cf487c4686
# 6 bfce39c89d6549f2bb94d8064d3ce69dc3d7e72b38f431d8aa0c4bf95ccee6bf
#   start_time       end_time         original_start_time original_end_time
# 1 30/06/2024 18:12 30/06/2024 18:24 1.71977e+12         1.71977e+12
# ...

# %% [markdown]
# The players data set contains multiple variables which are character types, so we'll change them to factors for easier manipulation later on.
#
# The new variable we create "much_time", is going to be the variable of interest throughout the project.
# Note that we will consider a playtime of 3 hours or greater as our baseline for a large amount of data provided. This amount of time was chosen as our benchmark since students in DSCI100 are all expected to contribute a minimum of 3 hours in order to gain participation marks for the project.

# %%
sessions_tidy <- sessions_data |>
        mutate(start_date = dmy_hm(start_time), end_date = dmy_hm(end_time)) |>
        mutate(session_length = end_date - start_date) |>
        select(-start_time, -end_time) |>
        separate(start_date, into = c("start_date", "start_time"), sep = " ") |>
        separate(end_date, into = c("end_date", "end_time"), sep = " ") |>
        rename(unix_start_time = original_start_time, unix_end_time = original_end_time)
head(sessions_tidy)
# Out:
# Warning message:
# “Expected 2 pieces. Missing pieces filled with `NA` in 3 rows [106, 1221, 1222].”
# Warning message:
# “Expected 2 pieces. Missing pieces filled with `NA` in 4 rows [52, 1063, 1066,
# 1238].”
#   hashedEmail
# 1 bfce39c89d6549f2bb94d8064d3ce69dc3d7e72b38f431d8aa0c4bf95ccee6bf
# 2 36d9cbb4c6bc0c1a6911436d2da0d09ec625e43e6552f575d4acc9cf487c4686
# 3 f8f5477f5a2e53616ae37421b1c660b971192bd8ff77e3398304c7ae42581fdc
# 4 bfce39c89d6549f2bb94d8064d3ce69dc3d7e72b38f431d8aa0c4bf95ccee6bf
# 5 36d9cbb4c6bc0c1a6911436d2da0d09ec625e43e6552f575d4acc9cf487c4686
# 6 bfce39c89d6549f2bb94d8064d3ce69dc3d7e72b38f431d8aa0c4bf95ccee6bf
#   unix_start_time unix_end_time start_date start_time end_date   end_time
# 1 1.71977e+12     1.71977e+12   2024-06-30 18:12:00   2024-06-30 18:24:00
# 2 1.71867e+12     1.71867e+12   2024-06-17 23:33:00   2024-06-17 23:46:00
# 3 1.72193e+12     1.72193e+12   2024-07-25 17:34:00   2024-07-25 17:57:00
# ...

# %%
plaicraft <- players |>
        filter(experience != "NA") |>
        mutate(much_time_ = as_factor(much_time)) |>
        select(-much_time)
head(plaicraft)
# Out:
#   experience played_hours gender age
# 1 Pro        30.3         Male    9
# 2 Veteran     3.8         Male   17
# 3 Veteran     0.0         Male   17
# 4 Amateur     0.7         Female 21
# 5 Regular     0.1         Male   21
# 6 Amateur     0.0         Female 17
#   hashedEmail                                                      much_time_
# 1 f6daba428a5e19a3d47574858c13550499be23603422e6a0ee9728f8b53e192d TRUE
# 2 f3c813577c458ba0dfef80996f8f32c93b6e8af1fa939732842f2312358a88e9 TRUE
# 3 b674dd7ee0d24096d1c019615ce4d12b20fcbff12d79d3c5a9d2118eb7ccbb28 FALSE
# 4 23fe711e0e3b77f1da7aa221ab1192afe21648d47d2b4fa7a5a659ff443a0eb5 FALSE
# 5 7dc01f10bf20671ecfccdac23812b1b415acd42c2147cb0af4d48fcce2420f3e FALSE
# 6 f58aad5996a435f16b0284a3b267f973f9af99e7a89bee0430055a44fa92f977 FALSE

# %% [markdown]
# Here is a summary of our wrangled data set after analyzing the variable provided in the player.csv and sessions.csv data sets.
#
# ![Screenshot 2024-12-01 at 11.51.40 PM.png](attachment:641b37df-7ec1-4e65-b1d7-eeeca22b5bce.png)

# %%
set.seed(1)

plaicraft_split <- initial_split(plaicraft, prop = 0.7, strata = much_time_)

plaicraft_train <- training(plaicraft_split)

plaicraft_test <- testing(plaicraft_split)

# %% [markdown]
# Once the code what split, we checked the training data to ensure that it contains about the same level of representation of each type of experienced player as the original data set.

# %%
count <- plaicraft_train |>
    group_by(experience) |>
    summarize(count = n()) |>
    arrange(count)
count

counts <- players_data |>
    group_by(experience) |>
    summarize(count = n()) |>
    arrange(count)
counts
# Out:
#   experience count
# 1 Pro         9
# 2 Regular    24
# 3 Beginner   27
# 4 Veteran    34
# 5 Amateur    43
#   experience count
# 1 Pro        14
# 2 Beginner   35
# 3 Regular    36
# 4 Veteran    48
# 5 Amateur    63

# %% [markdown]
# **Figure 1.0**
# Visualizing the age distribution within the Plaicraft participants

# %%
options(repr.plot.with = 10, repr.plot.height = 8)
players_age_plot <- plaicraft_train |>
        ggplot(aes(y = age, fill = much_time_)) +
        geom_bar(stat = "count") +
        labs(x = "Number of Players", y = "Age", title = "Time Spent Playing PLAIcraft \n Based on Experience", 
             fill = "If Time Spent Playing > 3 Hours") +
        ylim(c(8,50)) +
        theme(text = element_text(size = 16))
players_age_plot
# Out:
# Warning message:
# “Removed 2 rows containing non-finite outside the scale range (`stat_count()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range
# (`geom_bar()`).”
# plot without title

# %% [markdown]
# **Figure 2.0**
# Visualizing the experience level distribution within the Plaicraft participants

# %%
options(repr.plot.with = 10, repr.plot.height = 8)
players_time_plot <- plaicraft_train |>
        ggplot(aes(y = experience, fill = much_time_)) +
        geom_bar(stat = "count") +
        labs(x = "Number of Players", y = "Experience", title = "Time Spent Playing PLAIcraft \n Based on Experience", 
             fill = "If Time Spent Playing > 3 Hours") +
        theme(text = element_text(size = 16))
players_time_plot
# Out:
# plot without title

# %% [markdown]
# We choose the K value range we will be testing for to find the most optimal value.
# We also create 5 folds for our training data to complete five-fold cross-validation when tuning our KNN model.

# %%
set.seed(1)

test_ks <- tibble(neighbors = seq(from = 1, to = 15, by = 1))

vfold <- vfold_cv(plaicraft_train, v = 5, strata = much_time_)

# %% [markdown]
# Creating a model to predict if a potential participant will provide greater or equal to 3 hours of playtime based on experience alone.
# We go through the steps of creating our workflow recipe such as standardizing, scaling, and modifying our factor variables to be workable.
# Furthermore, we create a KNN model that uses tune() neighbors for us to determine the best K number for this workflow.

# %%
set.seed(1)

recipe <- recipe(much_time_ ~ experience, data = plaicraft_train) |>
        step_upsample(much_time_, over_ratio = 1, skip = TRUE) |>
        step_dummy(all_nominal_predictors())

spec_1 <- nearest_neighbor(weight_func = "rectangular", neighbors = tune()) |>
        set_engine("kknn") |>
        set_mode("classification")

workflow_1 <- workflow() |>
        add_recipe(recipe) |>
        add_model(spec_1) |>
        tune_grid(resamples = vfold, grid = test_ks) |>
        collect_metrics(truth = much_time_, control = "FALSE") |>
        filter(.metric == "accuracy")

options(repr.plot.width = 8, repr.plot.height = 8)
k_plot_1 <- ggplot(workflow_1, aes(x = neighbors, y = mean)) +
        geom_point() +
        geom_line() +
        labs(x = "Number of Neighbours", y = "Average Accuracy", 
             title = "Comparing the Accuracy of Various K Values") +
        scale_x_continuous(breaks = seq(1,15, by = 1)) +
        theme(text = element_text(size = 14))
k_plot_1
# Out:
# → A | warning: No control observations were detected in `truth` with control level 'TRUE'.
#
# There were issues with some computations   A: x1
#
# There were issues with some computations   A: x1
# plot without title

# %% [markdown]
# **Figure 3.0**
# Assembling the workflow #1 and collecting the accuracy measurements of the model, we create an optimal k-value chart. We determine the best K-value is from 1-10.

# %%
head(workflow_1)
# Out:
#   neighbors .metric  .estimator mean      n std_err    .config
# 1 1         accuracy binary     0.9417989 5 0.01456228 Preprocessor1_Model01
# 2 2         accuracy binary     0.9417989 5 0.01456228 Preprocessor1_Model02
# 3 3         accuracy binary     0.9417989 5 0.01456228 Preprocessor1_Model03
# 4 4         accuracy binary     0.9417989 5 0.01456228 Preprocessor1_Model04
# 5 5         accuracy binary     0.9417989 5 0.01456228 Preprocessor1_Model05
# 6 6         accuracy binary     0.9417989 5 0.01456228 Preprocessor1_Model06

# %% [markdown]
# The same steps taken to produce workflow #1 are repeated with different combinations of predictors to create workflows #2-6.

# %%
set.seed(1)

recipe_age <- recipe(much_time_ ~ age + experience, data = plaicraft_train) |>
         step_upsample(much_time_, over_ratio = 1, skip = TRUE) |>
        step_dummy(all_nominal_predictors())|>
         step_scale(age) |>
         step_center(age)

workflow_2 <- workflow() |>
        add_recipe(recipe_age) |>
        add_model(spec_1) |>
        tune_grid(resamples = vfold, grid = test_ks) |>
        collect_metrics() |>
        filter(.metric == "accuracy")

options(repr.plot.width = 8, repr.plot.height = 8)
k_plot_2 <- ggplot(workflow_2, aes(x = neighbors, y = mean)) +
        geom_point() +
        geom_line() +
        labs(x = "Number of Neighbours", y = "Average Accuracy", 
             title = "Comparing the Accuracy of Various K Values") +
        scale_x_continuous(breaks = seq(1,15, by = 1)) +
        theme(text = element_text(size = 14))
k_plot_2
# Out:
# → A | warning: No control observations were detected in `truth` with control level 'TRUE'.
#
# There were issues with some computations   A: x1
#
# There were issues with some computations   A: x1
# plot without title

# %% [markdown]
# **Figure 3.1**
# Assembling the workflow #2 and collecting the accuracy measurements of the model, we create an optimal k-value chart. We determine the best K-value is 2.

# %%
head(workflow_2)
# Out:
#   neighbors .metric  .estimator mean      n std_err    .config
# 1 1         accuracy binary     0.9272487 5 0.01993804 Preprocessor1_Model01
# 2 2         accuracy binary     0.9417989 5 0.01456228 Preprocessor1_Model02
# 3 3         accuracy binary     0.9272487 5 0.01109851 Preprocessor1_Model03
# 4 4         accuracy binary     0.9272487 5 0.01109851 Preprocessor1_Model04
# 5 5         accuracy binary     0.8904762 5 0.01175241 Preprocessor1_Model05
# 6 6         accuracy binary     0.8976190 5 0.01405855 Preprocessor1_Model06

# %%
set.seed(1)

recipe_age_gender <- recipe(much_time_ ~ age + gender, data = plaicraft_train) |>
         step_upsample(much_time_, over_ratio = 1, skip = TRUE) |>
        step_dummy(all_nominal_predictors())|>
         step_scale(age) |>
         step_center(age)

workflow_3 <- workflow() |>
        add_recipe(recipe_age_gender) |>
        add_model(spec_1) |>
        tune_grid(resamples = vfold, grid = test_ks) |>
        collect_metrics() |>
        filter(.metric == "accuracy")

options(repr.plot.width = 8, repr.plot.height = 8)
k_plot_3 <- ggplot(workflow_3, aes(x = neighbors, y = mean)) +
        geom_point() +
        geom_line() +
        labs(x = "Number of Neighbours", y = "Average Accuracy", 
             title = "Comparing the Accuracy of Various K Values") +
        scale_x_continuous(breaks = seq(1,15, by = 1)) +
        theme(text = element_text(size = 14))
k_plot_3
# Out:
# → A | warning: No control observations were detected in `truth` with control level 'TRUE'.
#
# There were issues with some computations   A: x1
#
# There were issues with some computations   A: x1
# plot without title

# %% [markdown]
# **Figure 3.2**
# Assembling the workflow #3 and collecting the accuracy measurements of the model, we create an optimal k-value chart. We determine the best K-value is 1 or 2.

# %%
head(workflow_3)
# Out:
#    neighbors .metric  .estimator mean      n std_err    .config
# 1   1        accuracy binary     0.9343915 5 0.01804768 Preprocessor1_Model01
# 2   2        accuracy binary     0.9343915 5 0.01804768 Preprocessor1_Model02
# 3   3        accuracy binary     0.9195767 5 0.01401367 Preprocessor1_Model03
# 4   4        accuracy binary     0.9195767 5 0.01401367 Preprocessor1_Model04
# 5   5        accuracy binary     0.9195767 5 0.01401367 Preprocessor1_Model05
# 6   6        accuracy binary     0.9195767 5 0.01401367 Preprocessor1_Model06
# 7   7        accuracy binary     0.9195767 5 0.01401367 Preprocessor1_Model07
# 8   8        accuracy binary     0.9195767 5 0.01401367 Preprocessor1_Model08
# 9   9        accuracy binary     0.9124339 5 0.01467241 Preprocessor1_Model09
# 10 10        accuracy binary     0.9124339 5 0.01467241 Preprocessor1_Model10
# 11 11        accuracy binary     0.8544974 5 0.03587315 Preprocessor1_Model11
# ...

# %%
set.seed(1)

recipe_age1 <- recipe(much_time_ ~ age, data = plaicraft_train) |>
         step_upsample(much_time_, over_ratio = 1, skip = TRUE) |>
         step_scale(age) |>
         step_center(age)

workflow_4 <- workflow() |>
        add_recipe(recipe_age1) |>
        add_model(spec_1) |>
        tune_grid(resamples = vfold, grid = test_ks) |>
        collect_metrics() |>
        filter(.metric == "accuracy")

options(repr.plot.width = 8, repr.plot.height = 8)
k_plot_4 <- ggplot(workflow_4, aes(x = neighbors, y = mean)) +
        geom_point() +
        geom_line() +
        labs(x = "Number of Neighbours", y = "Average Accuracy", 
             title = "Comparing the Accuracy of Various K Values") +
        scale_x_continuous(breaks = seq(1,15, by = 1)) +
        theme(text = element_text(size = 14))
k_plot_4
# Out:
# → A | warning: No control observations were detected in `truth` with control level 'TRUE'.
#
# There were issues with some computations   A: x1
#
# There were issues with some computations   A: x1
# plot without title

# %% [markdown]
# **Figure 3.3**
# Assembling the workflow #4 and collecting the accuracy measurements of the model, we create an optimal k-value chart. We determine the best K-value is 1 or 2.

# %%
head(workflow_4)
# Out:
#    neighbors .metric  .estimator mean      n std_err    .config
# 1   1        accuracy binary     0.9269841 5 0.02343324 Preprocessor1_Model01
# 2   2        accuracy binary     0.9269841 5 0.02343324 Preprocessor1_Model02
# 3   3        accuracy binary     0.9047619 5 0.02249455 Preprocessor1_Model03
# 4   4        accuracy binary     0.9047619 5 0.02536098 Preprocessor1_Model04
# 5   5        accuracy binary     0.8899471 5 0.03130872 Preprocessor1_Model05
# 6   6        accuracy binary     0.8899471 5 0.03130872 Preprocessor1_Model06
# 7   7        accuracy binary     0.8825397 5 0.03624049 Preprocessor1_Model07
# 8   8        accuracy binary     0.8825397 5 0.03624049 Preprocessor1_Model08
# 9   9        accuracy binary     0.8751323 5 0.04190763 Preprocessor1_Model09
# 10 10        accuracy binary     0.8751323 5 0.04190763 Preprocessor1_Model10
# 11 11        accuracy binary     0.8603175 5 0.05059347 Preprocessor1_Model11
# ...

# %%
set.seed(1)

recipe_gender1 <- recipe(much_time_ ~ gender, data = plaicraft_train) |>
         step_upsample(much_time_, over_ratio = 1, skip = TRUE) |>
        step_dummy(all_nominal_predictors())

workflow_5 <- workflow() |>
        add_recipe(recipe_gender) |>
        add_model(spec_1) |>
        tune_grid(resamples = vfold, grid = test_ks) |>
        collect_metrics() |>
        filter(.metric == "accuracy")

options(repr.plot.width = 8, repr.plot.height = 8)
k_plot_5 <- ggplot(workflow_5, aes(x = neighbors, y = mean)) +
        geom_point() +
        geom_line() +
        labs(x = "Number of Neighbours", y = "Average Accuracy", 
             title = "Comparing the Accuracy of Various K Values") +
        scale_x_continuous(breaks = seq(1,15, by = 1)) +
        theme(text = element_text(size = 14))
k_plot_5
# Out:
# → A | warning: No control observations were detected in `truth` with control level 'TRUE'.
#
# There were issues with some computations   A: x1
#
# There were issues with some computations   A: x1
# plot without title

# %% [markdown]
# **Figure 3.4**
# Assembling the workflow #5 and collecting the accuracy measurements of the model, we create an optimal k-value chart. We determine the best K-value is 1 or 2.

# %%
head(workflow_5)
# Out:
#    neighbors .metric  .estimator mean      n std_err    .config
# 1   1        accuracy binary     0.9343915 5 0.01804768 Preprocessor1_Model01
# 2   2        accuracy binary     0.9343915 5 0.01804768 Preprocessor1_Model02
# 3   3        accuracy binary     0.9195767 5 0.01401367 Preprocessor1_Model03
# 4   4        accuracy binary     0.9195767 5 0.01401367 Preprocessor1_Model04
# 5   5        accuracy binary     0.9195767 5 0.01401367 Preprocessor1_Model05
# 6   6        accuracy binary     0.9195767 5 0.01401367 Preprocessor1_Model06
# 7   7        accuracy binary     0.9195767 5 0.01401367 Preprocessor1_Model07
# 8   8        accuracy binary     0.9195767 5 0.01401367 Preprocessor1_Model08
# 9   9        accuracy binary     0.9124339 5 0.01467241 Preprocessor1_Model09
# 10 10        accuracy binary     0.9124339 5 0.01467241 Preprocessor1_Model10
# 11 11        accuracy binary     0.8544974 5 0.03587315 Preprocessor1_Model11
# ...

# %%
set.seed(1)

recipe_all <- recipe(much_time_ ~ age + gender + experience, data = plaicraft_train) |>
         step_upsample(much_time_, over_ratio = 1, skip = TRUE) |>
        step_dummy(all_nominal_predictors())|>
         step_scale(age) |>
         step_center(age)

workflow_6 <- workflow() |>
        add_recipe(recipe_all) |>
        add_model(spec_1) |>
        tune_grid(resamples = vfold, grid = test_ks) |>
        collect_metrics() |>
        filter(.metric == "accuracy")

options(repr.plot.width = 8, repr.plot.height = 8)
k_plot_6 <- ggplot(workflow_6, aes(x = neighbors, y = mean)) +
        geom_point() +
        geom_line() +
        labs(x = "Number of Neighbours", y = "Average Accuracy", 
             title = "Comparing the Accuracy of Various K Values") +
        scale_x_continuous(breaks = seq(1,15, by = 1)) +
        theme(text = element_text(size = 14))
k_plot_6
# Out:
# → A | warning: No control observations were detected in `truth` with control level 'TRUE'.
#
# There were issues with some computations   A: x1
#
# There were issues with some computations   A: x1
# plot without title

# %% [markdown]
# **Figure 3.5**
# Assembling the workflow #6 and collecting the accuracy measurements of the model, we create an optimal k-value chart. We determine the best K-value is 1 or 2.

# %%
head(workflow_6)
# Out:
#    neighbors .metric  .estimator mean      n std_err    .config
# 1   1        accuracy binary     0.9195767 5 0.00769473 Preprocessor1_Model01
# 2   2        accuracy binary     0.9195767 5 0.00769473 Preprocessor1_Model02
# 3   3        accuracy binary     0.8973545 5 0.01858266 Preprocessor1_Model03
# 4   4        accuracy binary     0.8899471 5 0.02903552 Preprocessor1_Model04
# 5   5        accuracy binary     0.8828042 5 0.02749796 Preprocessor1_Model05
# 6   6        accuracy binary     0.8679894 5 0.03471158 Preprocessor1_Model06
# 7   7        accuracy binary     0.8608466 5 0.02987896 Preprocessor1_Model07
# 8   8        accuracy binary     0.8608466 5 0.02987896 Preprocessor1_Model08
# 9   9        accuracy binary     0.8537037 5 0.02649336 Preprocessor1_Model09
# 10 10        accuracy binary     0.8537037 5 0.02649336 Preprocessor1_Model10
# 11 11        accuracy binary     0.7658730 5 0.02608203 Preprocessor1_Model11
# ...

# %% [markdown]
# Below we code for the max accuracy of each of the 6 different workflows, to see which one performed best on the training data.
#
# Although both workflows #1 and #2 produce the same max accuracy, our group decided to choose workflow #2 as having the best recipe and model as there was only one K value that produced the max accuracy (K = 2).

# %%
workflow_1 |>
    summarize(max = max(mean))

workflow_2 |>
    summarize(max = max(mean))

workflow_3 |>
    summarize(max = max(mean))

workflow_4 |>
    summarize(max = max(mean))

workflow_5 |>
    summarize(max = max(mean))

workflow_6 |>
    summarize(max = max(mean))
# Out:
#   max
# 1 0.9417989
#   max
# 1 0.9417989
#   max
# 1 0.9343915
#   max
# 1 0.9269841
#   max
# 1 0.9343915
#   max
# 1 0.9195767

# %% [markdown]
# Here we put everything together, using the recipe from workflow #2, and a K value of 2 neighbours. We perform our classifier on the test data and collect various metrics to evaluate its final performance.

# %%
set.seed(1)

spec_1.1 <- nearest_neighbor(weight_func = "rectangular", neighbors = 2) |>
        set_engine("kknn") |>
        set_mode("classification")

workflow_1.1 <- workflow() |>
        add_recipe(recipe_age) |>
        add_model(spec_1.1) |>
        fit(data = plaicraft_train)

test_predictions <- predict(workflow_1.1, plaicraft_test) |>
  bind_cols(plaicraft_test)


test_predictions |>
  metrics(truth = much_time_, estimate = .pred_class) |>
  filter(.metric == "accuracy")
head(test_predictions)


test_predictions |>
        precision(truth = much_time_, estimate = .pred_class)

test_predictions |>
        recall(truth = much_time_, estimate = .pred_class)
# Out:
#   .metric  .estimator .estimate
# 1 accuracy binary     0.779661
#   .pred_class experience played_hours gender age
# 1 FALSE       Veteran    0.0          Male   17
# 2 FALSE       Amateur    0.7          Female 21
# 3 FALSE       Regular    0.1          Male   21
# 4 FALSE       Amateur    0.0          Female 17
# 5 FALSE       Amateur    0.0          Male   21
# 6 FALSE       Amateur    0.1          Male   17
#   hashedEmail                                                      much_time_
# 1 b674dd7ee0d24096d1c019615ce4d12b20fcbff12d79d3c5a9d2118eb7ccbb28 FALSE
# 2 23fe711e0e3b77f1da7aa221ab1192afe21648d47d2b4fa7a5a659ff443a0eb5 FALSE
# 3 7dc01f10bf20671ecfccdac23812b1b415acd42c2147cb0af4d48fcce2420f3e FALSE
# 4 f58aad5996a435f16b0284a3b267f973f9af99e7a89bee0430055a44fa92f977 FALSE
# 5 1d2371d8a35c8831034b25bda8764539ab7db0f63938696917c447128a2540dd FALSE
# 6 8b71f4d66a38389b7528bb38ba6eb71157733df7d1740371852a797ae97d82d1 FALSE
#   .metric   .estimator .estimate
# ...

# %% [markdown]
# **Figure 4.0**
# A confusion matrix generated from our model which uses both experience and age as predictors.

# %%
confusion_matrix <- test_predictions |>
             conf_mat(truth = much_time_, estimate = .pred_class)
confusion_matrix

visualization <- autoplot(confusion_matrix, type = "heatmap") +
 scale_fill_gradient(low= "lightblue",high = "steelblue") +
theme(legend.position = "right") +
labs(title = "Confusion Matrix for Optimal K & Recipe",
    x = "Predicted Class",
    y = "Actual Class", fill = "Frequency") +
theme(text = element_text(size = 16))
visualization
# Out:
#           Truth
# Prediction FALSE TRUE
#      FALSE    46   11
#      TRUE      2    0
# Scale for fill is already present.
# Adding another scale for fill, which will replace the existing scale.
# plot without title

# %% [markdown]
# ## **Discussion**
#
# After creating two different K-NN classification models, we found that our final model has a relatively high accuracy, decent precision, high recall for true negatives, but an extremely poor recall for true positives. Our goal for this data analysis was to build a classifier that could identify whether a player is more likely to play 3 hours or more on PLAICraft, yet our model struggles to identify such true positives. The recall for true positives can be slightly improved by modifying the number of neighbours used, yet this diminishes the model’s accuracy and precision, making the trade-off not worth it as the recall is still very low.
#
# This is not what we expected to find as a group, as we did not anticipate running into such errors, yet in retrospect, the low recall for true positives makes sense. When going back to analyze the “plaicraft” data set, only about 19 observations out of the total 196 observations fit the criteria of being a true positive by having over 3 hours of play time. This highlights the underrepresentation of positives in the data set, which we tried to combat by using the “step_upsample()” function. However, R continued to give the warning that “No control observations were detected ... with control level ‘TRUE’ .” Despite our efforts, improving the model’s recall for what we deem as true positives is beyond our group’s scope of knowledge, yet the classifiers that we have built are still a strong foundation for further tuning.
#
# The impact of our final classifier having such a low recall to identify players that will spend more than 3 hours on PLAICraft, indicates that it is not reliable enough to predict which players should be targeted during recruiting efforts to increase website traffic on PLAICraft. Furthermore, the lack of observations for players that have spent 3 hours or more on PLAICraft indicates that the data collection of the “players.csv” data set may have been a bit premature. It is always best to have more data, and it is highly possible that if the “players.csv” data set what collected last week, the results of our classifier would be greatly different as more players would have additional time to spend 3 hours on PLAICraft, making the category more represented in the data set.
#
# All in all, our group’s data analysis brings up many different questions that can be explored to gain a better understanding of PLAICraft and its data. Should certain players be targeted for their play time, or should marketing efforts go into encouraging players of all kinds? What variable should targeting efforts be based on? Is quality of play time more important than quantity of play time? Is it possible to predict whether a player will spend more time on PLAICraft? Although our classifier still needs further tuning in order to predict whether a new player with contribute 3 hours or more to the PLAICraft play time data, recruiting efforts should focus on sending reminders to all the players who chose to subscribe to the PLAICraft emails in the meantime. This will still help the study’s cause in trying to collect as many hours on PLAICraft as possible that can be used to train human-AI.

# %% [markdown]
# **References**
#
# Kumar, N. (2024, October 16). How many people play minecraft 2024(Player count & revenue). DemandSage. https://www.demandsage.com/minecraft-statistics/
#
# RLave. (2020, February 11). Answer to ‘R how to visualize confusion matrix using the caret package’ [Online post]. Stack Overflow. https://stackoverflow.com/a/60164777
#
# Smith, andrew. (2023, September 28). Plaicraft. Ai launch. Pacific Laboratory for Artificial Intelligence. https://plai.cs.ubc.ca/2023/09/27/plaicraft/
